# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
import torch.nn.functional as F
from torch.autograd import Variable

import random
import os
import numpy as np
import pandas as pd
import math
import sys
from collections import Counter
from itertools import chain
from typing import List
import textwrap

import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm

#from google.colab import drive

random.seed(0)
torch.manual_seed(0)

# %%
drive.mount('/content/gdrive')

base_dir = "/content/gdrive/MyDrive/CS-5782-Projects/CS4782-Final"
sys.path.append(base_dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-90acc52f1425> in <module>
# ----> 1 drive.mount('/content/gdrive')
#       2
#       3 base_dir = "/content/gdrive/MyDrive/CS-5782-Projects/CS4782-Final"
#       4 sys.path.append(base_dir)
#
# NameError: name 'drive' is not defined

# %%
# %load_ext autoreload
# %autoreload 1

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(F"Device set to {device}")
# Out:
# Device set to cpu

# %%
from data_loader import TimeSeriesDataset
input_length    = 336   # e.g. past 336 steps
forecast_horizon= 96    # e.g. next 96 steps
batch_size      = 32

dataset = TimeSeriesDataset("data/ETTh1.csv", input_length, forecast_horizon)
n_total = len(dataset)
n_train = int(0.8 * n_total)
train_idx = list(range(0, n_train))
val_idx   = list(range(n_train, n_total))

train_ds = Subset(dataset, train_idx)
val_ds   = Subset(dataset, val_idx)

train_loader = DataLoader(
    train_ds,
    batch_size=batch_size,
    shuffle=True,     
    drop_last=True
)

val_loader = DataLoader(
    val_ds,
    batch_size=batch_size,
    shuffle=False
)

# %%
from PatchTST import PatchTST
from utils import train, val

criterion = nn.MSELoss()
model = PatchTST(input_length=input_length, patch_len=16,
                     stride=8, forecast_horizon=forecast_horizon)
optimizer = optim.Adam(model.parameters(), lr=1e-3, betas=(0.9, 0.98), eps=1e-9)
print('here')
train_loss_arr, val_loss_arr = train(
    model, train_loader, val_loader,
    criterion, epochs=10,
    optimizer=optimizer, device=device
)
# Out:
# here
# Starting training...
# Epoch 1/10
#   8%|▊         | 36/424 [01:35<17:12,  2.66s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-36cd99468c91> in <module>
#       7 optimizer = optim.Adam(model.parameters(), lr=1e-3, betas=(0.9, 0.98), eps=1e-9)
#       8 print('here')
# ----> 9 train_loss_arr, val_loss_arr = train(
#      10     model, train_loader, val_loader,
#      11     criterion, epochs=10,
#
# ~/cs4782/CS4782-Final/utils.py in train(model, train_loader, val_loader, criterion, epochs, optimizer, device)
#      42             outputs = model(inputs)
#      43             loss = criterion(outputs, labels)
# ---> 44             loss.backward()
#      45             optimizer.step()
#      46             running_loss += loss.item()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     520                 inputs=inputs,
#     521             )
# --> 522         torch.autograd.backward(
#     523             self, gradient, retain_graph, create_graph, inputs=inputs
#     524         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     264     # some Python versions print out the first line of a multi-line function
#     265     # calls in the traceback and some print out the last line
# --> 266     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267         tensors,
#     268         grad_tensors_,
#
# KeyboardInterrupt:
